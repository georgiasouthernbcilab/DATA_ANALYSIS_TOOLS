# %%
from participant_handler import Participant

# testParticipant = participant_handler.Participant

participant1 = Participant(r'103918\split')
print(participant1.angry_pow_df)
# print(participant1.angry_pow_df_stats)
# participant1.angry_pow_df.angry_pow_df_stats
# Out:
#             POW.Cz.Theta  POW.Cz.Alpha  POW.Cz.BetaL  POW.Cz.BetaH  \
# Timestamp
# 1713363773      1.476770      0.868653      0.688564      0.183709
# 1713363773      1.252587      0.821755      0.762084      0.183472
# 1713363773      1.010022      0.759513      0.825604      0.178493
# 1713363773      0.838750      0.708362      0.858672      0.171375
# 1713363773      0.798966      0.705716      0.847494      0.169788
# ...                  ...           ...           ...           ...
# 1713363837      1.260795      1.491476      0.295718      0.181020
# 1713363838      1.247194      1.532722      0.310925      0.195544
# 1713363838      1.240676      1.466961      0.346837      0.211573
# 1713363838      1.240062      1.323356      0.401511      0.229800
# 1713363838      1.262811      1.155714      0.464112      0.249896
#
#             POW.Cz.Gamma  POW.Fz.Theta  POW.Fz.Alpha  POW.Fz.BetaL  \
# Timestamp
# 1713363773      0.099402      0.911377      0.445650      0.422592
# ...
